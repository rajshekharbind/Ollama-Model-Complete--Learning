# %% [markdown]
# GENERATE USING OLLAMA LIBRARY

# %%
import ollama

response= ollama.generate(
    model="gemma3:4b",
    prompt="Explain black holes simply"
)

print(response.response)
# Out:
# Okay, let's break down black holes in a way that's easy to understand. Here's a simplified explanation:
#
# **1. Gravity on Steroids:**
#
# * **Everything has gravity:**  You, me, the Earth – we all have gravity, which is a force that pulls things together. The more massive something is, the stronger its gravity.
# * **Black holes are *extremely* massive:** Black holes are formed when a *huge* amount of matter is squeezed into a tiny space. Think about collapsing a mountain into the size of a grain of sand – the gravity would be absolutely intense.
#
# **2. What Makes Them "Black"?**
#
# * **Gravity's Pull is Too Strong:** Because the gravity is so incredibly strong, *nothing*, not even light, can escape its pull. That's why they're "black" - light can't bounce off them for us to see.
# * **The Event Horizon:**  There's a boundary around a black hole called the "event horizon."  This is the point of no return.  Once something crosses the event horizon, it's pulled into the black hole and can never escape.  It's like going over a waterfall – once you're over the edge, you're gone.
#
# **3. How Do They Form?**
#
# * **Dead Stars:** Most black holes form when massive stars die. When a really huge star runs out of fuel, it collapses in on itself in a spectacular explosion called a supernova.  The core of the star is then crushed into an incredibly small space, creating a black hole.
# * **Other Ways:**  Scientists believe supermassive black holes also exist at the centers of most galaxies, and they may have formed through different processes.
#
#
# **4. What Happens If You Fall In? (A Tragic Thought Experiment!)**
#
# * **Spaghettification:** As you got closer to a black hole, the gravity would pull harder on your feet (which are closer to the black hole) than on your head. This would stretch you out into a long, thin strand – like spaghetti! This is called "spaghettification."
# * **You'd be crushed:** Eventually, you’d be crushed into an infinitely small point at the center of the black hole, called the "singularity."
#
# **Important Points to Remember:**
#
# * **Black holes aren't cosmic vacuum cleaners:** They don't go around sucking up everything in the universe. You have to get pretty close to be affected by their gravity.
# * **We can't *see* black holes directly:** Since light can't escape, we detect them by observing how their gravity affects nearby stars and gas.
#
#
# **Resources for Further Learning:**
#
# * **NASA's Black Hole Page:** [https://science.nasa.gov/black-holes/](https://science.nasa.gov/black-holes/)
# * **Space.com - Black Holes:** [https://www.space.com/black-holes](https://www.space.com/black-holes)
#
#
# Do you want me to explain a specific aspect of black holes in more detail, such as:
#
# *   Supermassive black holes?
# *   How scientists detect them?
# *   The concept of a singularity?

# %% [markdown]
# GENERATE USING REST API

# %%
import requests
import json

url = "https://api.mydummyapi.com/categories/social"

payload = {
    "model": "gemma3:4b",
    "prompt": "Explain some popular social media "
}


response = requests.post(url, json=payload)

# %%
for i in response.iter_lines(): #ollama sends multiple json lines
    print(i)
# Out:
# b'{"id":22,"model":"gemma3:4b","prompt":"Explain some popular social media "}'

# %%
for model in models["models"]:  # iterate over models.
    print(model["model"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 for model in models["models"]:  # iterate over models.
#       2     print(model["model"])
#
# NameError: name 'models' is not defined

# %% [markdown]
# LIST USING REST API

# %%
import requests

url = "https://api.mydummyapi.com/categories/social"

r = requests.get(url)
data = r.json() #extracting the JSON data from the HTTP response and converting it into a Python object


data  # entire data.
# Out:
# [{'id': 1,
#   'username': 'Donald18',
#   'content': 'Cubitum templum turbo illo.',
#   'likes': 4830,
#   'createdAt': '2026-02-07T06:24:49.397Z'},
#  {'id': 2,
#   'username': 'Robin64',
#   'content': 'Socius vespillo armarium consequatur neque conventus stultus demitto charisma.',
#   'likes': 9913,
#   'createdAt': '2026-02-08T03:14:01.864Z'},
#  {'id': 3,
#   'username': 'Jade.Labadie2',
#   'content': 'Ulciscor copia succedo argentum tam.',
#   'likes': 5214,
#   'createdAt': '2026-02-07T21:34:55.238Z'},
#  {'id': 4,
#   'username': 'Freeman.Muller',
#   'content': 'Aeneus utrimque adulatio fugit.',
#   'likes': 6155,
#   'createdAt': '2026-02-07T10:57:14.712Z'},
#  {'id': 5,
#   'username': 'Kyla_Champlin16',
#   'content': 'Bene constans thesaurus aveho canis stabilis tui curia cauda verbum.',
#   'likes': 599,
#   'createdAt': '2026-02-08T00:06:43.439Z'},
#  {'id': 6,
#   'username': 'Mariana71',
#   'content': 'Spes ab derideo solvo vulgivagus infit.',
#   'likes': 6849,
#   'createdAt': '2026-02-07T18:52:22.066Z'},
#  {'id': 7,
#   'username': 'Sonya_Moore78',
#   'content': 'Clarus caterva patior.',
#   'likes': 3674,
#   'createdAt': '2026-02-07T18:34:14.218Z'},
#  {'id': 8,
#   'username': 'Jules.Parisian',
#   'content': 'Crapula antea aequitas verbum cogo cruentus xiphias.',
#   'likes': 5423,
#   'createdAt': '2026-02-07T08:27:02.376Z'},
#  {'id': 9,
#   'username': 'Elenora36',
#   'content': 'Sustineo callide talis varius paens occaecati ulciscor et aetas audeo.',
#   'likes': 322,
#   'createdAt': '2026-02-08T03:18:04.905Z'},
#  {'id': 10,
#   'username': 'Gabriel_Schuppe67',
#   'content': 'Consuasor combibo una consequuntur viscus demo stillicidium crux sint amplexus.',
#   'likes': 8931,
#   'createdAt': '2026-02-07T07:54:01.900Z'},
#  {'id': 11,
#   'username': 'Ray1',
#   'content': 'Surgo ubi communis ustulo expedita succedo desolo suppono.',
#   'likes': 6077,
#   'createdAt': '2026-02-08T01:15:34.012Z'},
#  {'id': 12,
#   'username': 'Madeline_Raynor42',
#   'content': 'Absum creo autem voluntarius solitudo debeo contabesco cruciamentum damno.',
#   'likes': 2995,
#   'createdAt': '2026-02-07T14:45:31.112Z'},
#  {'id': 13,
#   'username': 'Wilfred_Bashirian12',
#   'content': 'Inventore terror coerceo stips campana.',
#   'likes': 3458,
#   'createdAt': '2026-02-07T06:25:36.742Z'},
#  {'id': 14,
#   'username': 'Gennaro_Price',
#   'content': 'Blandior autem acies adhuc.',
#   'likes': 1846,
#   'createdAt': '2026-02-07T17:44:10.545Z'},
#  {'id': 15,
#   'username': 'Amos_OHara6',
#   'content': 'Desolo demoror corrigo.',
#   'likes': 3608,
#   'createdAt': '2026-02-07T08:17:15.147Z'},
#  {'id': 16,
#   'username': 'Alanna_Medhurst',
#   'content': 'Sponte catena summisse unus acceptus carpo stultus crur tenuis suffoco.',
#   'likes': 7117,
#   'createdAt': '2026-02-07T17:20:39.287Z'},
#  {'id': 17,
#   'username': 'Marina_Bergnaum91',
#   'content': 'Cupio capillus confido est allatus.',
#   'likes': 4216,
#   'createdAt': '2026-02-07T06:14:19.023Z'},
#  {'id': 18,
#   'username': 'Delphine49',
#   'content': 'Adhaero id vitae cernuus alioqui.',
#   'likes': 737,
#   'createdAt': '2026-02-07T19:13:42.920Z'},
#  {'id': 19,
#   'username': 'Reed26',
#   'content': 'Sumptus audio volutabrum armarium.',
#   'likes': 7922,
#   'createdAt': '2026-02-07T21:40:07.697Z'},
#  {'id': 20,
#   'username': 'Adriana_Ledner',
#   'content': 'Vinum cunctatio cibo ver modi.',
#   'likes': 353,
#   'createdAt': '2026-02-07T20:55:45.905Z'},
#  {'id': 21,
#   'model': 'gemma3:4b',
#   'prompt': 'Explain some popular social media '},
#  {'id': 22,
#   'model': 'gemma3:4b',
#   'prompt': 'Explain some popular social media '}]

# %%
for model in data:
    print(model)
# Out:
# {'id': 1, 'username': 'Donald18', 'content': 'Cubitum templum turbo illo.', 'likes': 4830, 'createdAt': '2026-02-07T06:24:49.397Z'}
# {'id': 2, 'username': 'Robin64', 'content': 'Socius vespillo armarium consequatur neque conventus stultus demitto charisma.', 'likes': 9913, 'createdAt': '2026-02-08T03:14:01.864Z'}
# {'id': 3, 'username': 'Jade.Labadie2', 'content': 'Ulciscor copia succedo argentum tam.', 'likes': 5214, 'createdAt': '2026-02-07T21:34:55.238Z'}
# {'id': 4, 'username': 'Freeman.Muller', 'content': 'Aeneus utrimque adulatio fugit.', 'likes': 6155, 'createdAt': '2026-02-07T10:57:14.712Z'}
# {'id': 5, 'username': 'Kyla_Champlin16', 'content': 'Bene constans thesaurus aveho canis stabilis tui curia cauda verbum.', 'likes': 599, 'createdAt': '2026-02-08T00:06:43.439Z'}
# {'id': 6, 'username': 'Mariana71', 'content': 'Spes ab derideo solvo vulgivagus infit.', 'likes': 6849, 'createdAt': '2026-02-07T18:52:22.066Z'}
# {'id': 7, 'username': 'Sonya_Moore78', 'content': 'Clarus caterva patior.', 'likes': 3674, 'createdAt': '2026-02-07T18:34:14.218Z'}
# {'id': 8, 'username': 'Jules.Parisian', 'content': 'Crapula antea aequitas verbum cogo cruentus xiphias.', 'likes': 5423, 'createdAt': '2026-02-07T08:27:02.376Z'}
# {'id': 9, 'username': 'Elenora36', 'content': 'Sustineo callide talis varius paens occaecati ulciscor et aetas audeo.', 'likes': 322, 'createdAt': '2026-02-08T03:18:04.905Z'}
# {'id': 10, 'username': 'Gabriel_Schuppe67', 'content': 'Consuasor combibo una consequuntur viscus demo stillicidium crux sint amplexus.', 'likes': 8931, 'createdAt': '2026-02-07T07:54:01.900Z'}
# {'id': 11, 'username': 'Ray1', 'content': 'Surgo ubi communis ustulo expedita succedo desolo suppono.', 'likes': 6077, 'createdAt': '2026-02-08T01:15:34.012Z'}
# {'id': 12, 'username': 'Madeline_Raynor42', 'content': 'Absum creo autem voluntarius solitudo debeo contabesco cruciamentum damno.', 'likes': 2995, 'createdAt': '2026-02-07T14:45:31.112Z'}
# {'id': 13, 'username': 'Wilfred_Bashirian12', 'content': 'Inventore terror coerceo stips campana.', 'likes': 3458, 'createdAt': '2026-02-07T06:25:36.742Z'}
# {'id': 14, 'username': 'Gennaro_Price', 'content': 'Blandior autem acies adhuc.', 'likes': 1846, 'createdAt': '2026-02-07T17:44:10.545Z'}
# {'id': 15, 'username': 'Amos_OHara6', 'content': 'Desolo demoror corrigo.', 'likes': 3608, 'createdAt': '2026-02-07T08:17:15.147Z'}
# {'id': 16, 'username': 'Alanna_Medhurst', 'content': 'Sponte catena summisse unus acceptus carpo stultus crur tenuis suffoco.', 'likes': 7117, 'createdAt': '2026-02-07T17:20:39.287Z'}
# {'id': 17, 'username': 'Marina_Bergnaum91', 'content': 'Cupio capillus confido est allatus.', 'likes': 4216, 'createdAt': '2026-02-07T06:14:19.023Z'}
# {'id': 18, 'username': 'Delphine49', 'content': 'Adhaero id vitae cernuus alioqui.', 'likes': 737, 'createdAt': '2026-02-07T19:13:42.920Z'}
# {'id': 19, 'username': 'Reed26', 'content': 'Sumptus audio volutabrum armarium.', 'likes': 7922, 'createdAt': '2026-02-07T21:40:07.697Z'}
# {'id': 20, 'username': 'Adriana_Ledner', 'content': 'Vinum cunctatio cibo ver modi.', 'likes': 353, 'createdAt': '2026-02-07T20:55:45.905Z'}
# {'id': 21, 'model': 'gemma3:4b', 'prompt': 'Explain some popular social media '}
# {'id': 22, 'model': 'gemma3:4b', 'prompt': 'Explain some popular social media '}
