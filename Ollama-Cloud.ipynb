# %%
pip install ollama
# Out:
# Requirement already satisfied: ollama in c:\users\bramh\anaconda3\envs\ml\lib\site-packages (0.6.1)
# Requirement already satisfied: httpx>=0.27 in c:\users\bramh\anaconda3\envs\ml\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in c:\users\bramh\appdata\roaming\python\python310\site-packages (from ollama) (2.11.7)
# Requirement already satisfied: anyio in c:\users\bramh\appdata\roaming\python\python310\site-packages (from httpx>=0.27->ollama) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\users\bramh\appdata\roaming\python\python310\site-packages (from httpx>=0.27->ollama) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\bramh\appdata\roaming\python\python310\site-packages (from httpx>=0.27->ollama) (1.0.7)
# Requirement already satisfied: idna in c:\users\bramh\appdata\roaming\python\python310\site-packages (from httpx>=0.27->ollama) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bramh\appdata\roaming\python\python310\site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\bramh\appdata\roaming\python\python310\site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\bramh\appdata\roaming\python\python310\site-packages (from pydantic>=2.9->ollama) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\bramh\appdata\roaming\python\python310\site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\bramh\appdata\roaming\python\python310\site-packages (from pydantic>=2.9->ollama) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\bramh\appdata\roaming\python\python310\site-packages (from anyio->httpx>=0.27->ollama) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\bramh\appdata\roaming\python\python310\site-packages (from anyio->httpx>=0.27->ollama) (1.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ollama 

response = ollama.generate(
    model="deepseek-v3.1:671b-cloud",
    prompt="Why do stars twinkle?"
)
print(response["response"])
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[2], line 3
#       1 import ollama
# ----> 3 response = ollama.generate(
#       4     model="deepseek-v3.1:671b-cloud",
#       5     prompt="Why do stars twinkle?"
#       6 )
#       7 print(response["response"])
#
# File ~\anaconda3\envs\ml\lib\site-packages\ollama\_client.py:262, in Client.generate(self, model, prompt, suffix, system, template, context, stream, think, logprobs, top_logprobs, raw, format, images, options, keep_alive)
#     233 def generate(
#     234   self,
#     235   model: str = '',
#    (...)
#     250   keep_alive: Optional[Union[float, str]] = None,
#     251 ) -> Union[GenerateResponse, Iterator[GenerateResponse]]:
#     252   """
#     253   Create a response using the requested model.
#     254
#    (...)
#     259   Returns `GenerateResponse` if `stream` is `False`, otherwise returns a `GenerateResponse` generator.
#     260   """
# --> 262   return self._request(
#     263     GenerateResponse,
#     264     'POST',
#     265     '/api/generate',
#     266     json=GenerateRequest(
#     267       model=model,
#     268       prompt=prompt,
#     269       suffix=suffix,
#     270       system=system,
#     271       template=template,
#     272       context=context,
#     273       stream=stream,
#     274       think=think,
#     275       logprobs=logprobs,
#     276       top_logprobs=top_logprobs,
#     277       raw=raw,
#     278       format=format,
#     279       images=list(_copy_images(images)) if images else None,
#     280       options=options,
#     281       keep_alive=keep_alive,
#     282     ).model_dump(exclude_none=True),
#     283     stream=stream,
#     284   )
#
# File ~\anaconda3\envs\ml\lib\site-packages\ollama\_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~\anaconda3\envs\ml\lib\site-packages\ollama\_client.py:133, in Client._request_raw(self, *args, **kwargs)
#     131   return r
#     132 except httpx.HTTPStatusError as e:
# --> 133   raise ResponseError(e.response.text, e.response.status_code) from None
#     134 except httpx.ConnectError:
#     135   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: model 'deepseek-v3.1:671b-cloud' not found (status code: 404)
